# %%
import pandas as pd # IMPORTING THE PANDAS LIBRARY

# %%
df = pd.read_csv("C:/Users/Moham/OneDrive/Desktop/python/customer_analytics (1).csv")

# %%
df.head() # GIVE FIRST 5 ROWS
# Out:
#    CustomerID  Age  Gender    City  Education MaritalStatus  AnnualIncome  \
# 0        1001   49    Male    Pune    Masters        Single       82953.0
# 1        1002   44    Male    Pune        PhD        Single       60610.0
# 2        1003   42    Male  Mumbai  Bachelors        Single       35501.0
# 3        1004   36  Female  Mumbai    Masters       Married       99312.0
# 4        1005   23    Male    Pune    Masters       Married       46980.0
#
#    SpendingScore  YearsEmployed  PurchaseFrequency  OnlineVisitsPerMonth  \
# 0             66             23                 19                     9
# 1             56             22                  1                    23
# 2             44             18                 10                    29
# 3             36             10                 12                    21
# 4             56              1                 18                     9
#
#    ReturnedItems PreferredDevice  LastPurchaseAmount
# ...

# %% [markdown]
# COLOUNM :-
# CustomerID	,Age	,Gender	,City	,Education,	MaritalStatus,	AnnualIncome,	SpendingScore,	YearsEmployed,	PurchaseFrequency	OnlineVisitsPerMonth,	ReturnedItems,	PreferredDevice,	LastPurchaseAmount

# %%
df.info()  #GIVE THE DATATYPE OF EACH COLOUNM
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CustomerID            255 non-null    int64
#  1   Age                   255 non-null    int64
#  2   Gender                255 non-null    object
#  3   City                  255 non-null    object
#  4   Education             243 non-null    object
#  5   MaritalStatus         255 non-null    object
#  6   AnnualIncome          243 non-null    float64
#  7   SpendingScore         255 non-null    int64
#  8   YearsEmployed         255 non-null    int64
#  9   PurchaseFrequency     255 non-null    int64
#  10  OnlineVisitsPerMonth  255 non-null    int64
#  11  ReturnedItems         255 non-null    int64
#  12  PreferredDevice       255 non-null    object
#  13  LastPurchaseAmount    255 non-null    int64
# dtypes: float64(1), int64(8), object(5)
# ...

# %% [markdown]
# INFO COMMAND HELPS IN KNOW THE DTYPE MEAN DATATYPE OF THE EACH COLONUM

# %%
df.describe() # GIVES THE MEAN,STD,MIN,25%,50%,75%,MAX
# Out:
#         CustomerID         Age   AnnualIncome  SpendingScore  YearsEmployed  \
# count   255.000000  255.000000     243.000000     255.000000     255.000000
# mean   1126.941176   37.729412   74499.901235      45.721569      14.682353
# std      72.397256    9.767842   43939.855655      17.869522       9.651664
# min    1001.000000   21.000000   16062.000000       5.000000       1.000000
# 25%    1064.500000   29.000000   56353.000000      34.500000       6.000000
# 50%    1128.000000   38.000000   69629.000000      47.000000      15.000000
# 75%    1190.500000   46.000000   84030.500000      57.500000      23.000000
# max    1250.000000   54.000000  474327.000000      95.000000      34.000000
#
#        PurchaseFrequency  OnlineVisitsPerMonth  ReturnedItems  \
# count         255.000000            255.000000     255.000000
# mean           11.568627             16.078431       1.858824
# std             7.077899              7.909536       1.409917
# ...

# %% [markdown]
# ROW USED:-
# COUT FOR COUNTING THE ROWA
# MEAN IS AVERAGE
# STD IS STANDARD DEVIATION HOW THE DATA IS DIVIATED
# 25%
# 75%
# MAX MAX ELEMENT OF COLOUNM

# %%
df.isnull().sum() # HERE WE ARE FINDING THE NULL VALUE AND ADDDING THEM
# Out:
# CustomerID               0
# Age                      0
# Gender                   0
# City                     0
# Education               12
# MaritalStatus            0
# AnnualIncome            12
# SpendingScore            0
# YearsEmployed            0
# PurchaseFrequency        0
# OnlineVisitsPerMonth     0
# ReturnedItems            0
# PreferredDevice          0
# LastPurchaseAmount       0
# dtype: int64

# %%
# Out:
# np.int64(5)

# %%
df.count()
# Out:
# CustomerID              255
# Age                     255
# Gender                  255
# City                    255
# Education               243
# MaritalStatus           255
# AnnualIncome            243
# SpendingScore           255
# YearsEmployed           255
# PurchaseFrequency       255
# OnlineVisitsPerMonth    255
# ReturnedItems           255
# PreferredDevice         255
# LastPurchaseAmount      255
# dtype: int64

# %%
(12/243)*100
# Out:
# 4.938271604938271

# %% [markdown]
# FOR EDUCATION WE CAN USE THE MODE FOR FILL NULL VALUES

# %%
df["Education"].fillna(df["Education"].mode()[0], inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerID               0
# Age                      0
# Gender                   0
# City                     0
# Education                0
# MaritalStatus            0
# AnnualIncome            12
# SpendingScore            0
# YearsEmployed            0
# PurchaseFrequency        0
# OnlineVisitsPerMonth     0
# ReturnedItems            0
# PreferredDevice          0
# LastPurchaseAmount       0
# dtype: int64

# %% [markdown]
# WE HAVE USED MEDIAN OF SALARY BECAUSE SALARY IS NUMERICAL VALUE AND MEDIUN IS GOOD THAN MODE SO WE CAN USE THEM FOR FILLING NULL VALUES

# %%
df["AnnualIncome"] = df["AnnualIncome"].fillna(df["AnnualIncome"].median())

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Age                     0
# Gender                  0
# City                    0
# Education               0
# MaritalStatus           0
# AnnualIncome            0
# SpendingScore           0
# YearsEmployed           0
# PurchaseFrequency       0
# OnlineVisitsPerMonth    0
# ReturnedItems           0
# PreferredDevice         0
# LastPurchaseAmount      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

plt.hist(df['Age'],bins=10, color='steelblue', edgecolor='black')
plt.title('AGE')
plt.xlabel('RANGE')
plt.ylabel('COUNT')
plt.show()

# %% [markdown]
# this is the histogram in which age is x axis and range of the is y axis

# %%
import matplotlib.pyplot as plt

categories = df['Gender'].value_counts()
plt.bar(counts.index, counts.values, color='steelblue', edgecolor='black')
plt.title('count ')
plt.xlabel('Gender')
plt.ylabel('Gender vs count')
plt.show()

# %% [markdown]
# HERE WE USE THE value_counts() for the couting the gender for each male and female and use the gender is used at x axis

# %%
import matplotlib.pyplot as plt

plt.scatter(df["Age"], df["AnnualIncome"])
plt.xlabel("AGE")
plt.ylabel("Salary")
plt.title("AGE vs Salary Offered")
plt.show()

# %%
WE ARE USING THE NUMERICAL-NUMERICAL value so we are ploting the scatter plot here we see the some outlier also here

# %%
import matplotlib.pyplot as plt

plt.boxplot(df["Age"])
plt.title("Box Plot of AGE")
plt.ylabel("AGE")
plt.show()

# %% [markdown]
# box plot show the range of the element and outlier and min max

# %%
import seaborn as sns
import matplotlib.pyplot as plt
corr_matrix = df.corr(numeric_only=True)
corr_matrix
# Out:
#                       CustomerID       Age  AnnualIncome  SpendingScore  \
# CustomerID              1.000000 -0.030988     -0.038365       0.052029
# Age                    -0.030988  1.000000     -0.049048      -0.002351
# AnnualIncome           -0.038365 -0.049048      1.000000      -0.374378
# SpendingScore           0.052029 -0.002351     -0.374378       1.000000
# YearsEmployed          -0.011019  0.974985     -0.052169      -0.014257
# PurchaseFrequency      -0.079962  0.102801     -0.038986       0.006548
# OnlineVisitsPerMonth   -0.021931 -0.041306      0.088933      -0.085304
# ReturnedItems           0.021826 -0.056243     -0.116884       0.045469
# LastPurchaseAmount     -0.038018  0.076649     -0.022261       0.024245
#
#                       YearsEmployed  PurchaseFrequency  OnlineVisitsPerMonth  \
# CustomerID                -0.011019          -0.079962             -0.021931
# Age                        0.974985           0.102801             -0.041306
# ...

# %% [markdown]
# it is correlation in which if done with itself it gives the 1 and correlation with other element and givs the value

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, 
            annot=True, 
            cmap="coolwarm", 
            fmt=".2f",
            linewidths=0.5)

plt.title("Correlation Matrix Heatmap")
plt.show()

# %% [markdown]
# is is heatmap show the correlation matrix in graphial format we use coolwarm so it give in red white and blue

# %% [markdown]
# SUMMARY
# 1.this is the histogram in which age is x axis and range of the is y axis
# 2.HERE WE USE THE value_counts() for the couting the gender for each male and female and use the gender is used at x axis
# 3.WE ARE USING THE NUMERICAL-NUMERICAL value so we are ploting the scatter plot here we see the some outlier also here
# 4.box plot show the range of the element and outlier and min max
# 5.it is correlation in which if done with itself it gives the 1 and correlation with other element and givs the value
# 6.is is heatmap show the correlation matrix in graphial format we use coolwarm so it give in red white and blue
